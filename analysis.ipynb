# %% [markdown]
# # Analysis of integrated data
#
# Import Python modules:

# %%
import re

import altair as alt

import pandas as pd

# %% [markdown]
# ## Read integrated data
# The general structure of the dataframe is that each cell barcode is listed on a row, and features of that cell are listed in columns.
# Cells that have more than one valid viral barcode identified may have multiple rows--one for each valid viral barcode.

# %%
integrated_data_csv = 'results/viral_fastq10x/scProgenyProduction_trial3_integrate_data.csv.gz'

integrated_data = pd.read_csv(integrated_data_csv)

integrated_data
# Out:
#           cell_barcode    infected infecting_viral_tag  total_UMIs  \
# 0     AAACCCAGTAACAAGT  uninfected                none       47873
# 1     AAACCCATCATTGCTT  uninfected                none       90114
# 2     AAACGAAAGATGTTGA  uninfected                none      111630
# 3     AAACGAAGTACTTCCC    infected                both       56828
# 4     AAACGAAGTAGACGTG    infected                  wt      124341
# ...                ...         ...                 ...         ...
# 3974  TTTGATCTCGCATTGA    infected                  wt      170914
# 3975  TTTGGAGAGTTGCCTA  uninfected                none       65941
# 3976  TTTGGAGGTATCGTTG    infected                  wt      150130
# 3977  TTTGGAGGTATCGTTG    infected                  wt      150130
# 3978  TTTGTTGAGTGCAGCA  uninfected                none      135009
#
#       viral_UMIs  frac_viral_UMIs  n_viral_genes  frac_UMIs_fluHA  \
# 0              6         0.000125              0         0.000042
# 1             10         0.000111              1         0.000000
# 2             18         0.000161              0         0.000027
# 3          24082         0.423770              7         0.000035
# 4           4654         0.037429              8         0.002566
# ...          ...              ...            ...              ...
# 3974       10415         0.060937              8         0.003604
# 3975          12         0.000182              1         0.000000
# 3976        3526         0.023486              8         0.000619
# 3977        3526         0.023486              8         0.000619
# 3978           8         0.000059              1         0.000015
#
#       frac_UMIs_fluM  frac_UMIs_fluNA  ...  barcoded_gene     viral_barcode  \
# 0           0.000063         0.000000  ...            NaN               NaN
# 1           0.000055         0.000000  ...            NaN               NaN
# 2           0.000090         0.000000  ...            NaN               NaN
# 3           0.229816         0.007391  ...            NaN               NaN
# 4           0.012723         0.000249  ...          fluHA  AAGTAAGCGACATGAG
# ...              ...              ...  ...            ...               ...
# 3974        0.028324         0.007864  ...          fluHA  GGTCACTTGGGTACTG
# 3975        0.000091         0.000015  ...            NaN               NaN
# 3976        0.011110         0.000300  ...          fluHA  AGTAAACTTCCTCGCG
# 3977        0.011110         0.000300  ...          fluNA  ACATCTTATTTACACG
# 3978        0.000015         0.000007  ...            NaN               NaN
#
#       viral_bc_UMIs  frac_viral_bc_UMIs  freq_second_infection  \
# 0               NaN                 NaN                    NaN
# 1               NaN                 NaN                    NaN
# 2               NaN                 NaN                    NaN
# 3               NaN                 NaN                    NaN
# 4             251.0            0.002019               0.000010
# ...             ...                 ...                    ...
# 3974          363.0            0.002124               0.000010
# 3975            NaN                 NaN                    NaN
# 3976           65.0            0.000433               0.000010
# 3977           39.0            0.000260               0.000028
# 3978            NaN                 NaN                    NaN
#
#       freq_supernatant  max_freq_second_infection  max_freq_supernatant  \
# 0                  NaN                        NaN                   NaN
# 1                  NaN                        NaN                   NaN
# 2                  NaN                        NaN                   NaN
# 3                  NaN                        NaN                   NaN
# 4             0.000076                   0.000010              0.000076
# ...                ...                        ...                   ...
# 3974          0.000010                   0.000010              0.000010
# 3975               NaN                        NaN                   NaN
# 3976          0.000695                   0.000028              0.001790
# 3977          0.001790                   0.000028              0.001790
# 3978               NaN                        NaN                   NaN
#
#       contributes_progeny_second_infection  contributes_progeny_supernatant
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                    False                             True
# ...                                    ...                              ...
# 3974                                 False                            False
# 3975                                   NaN                              NaN
# 3976                                  True                             True
# 3977                                  True                             True
# 3978                                   NaN                              NaN
#
# [3979 rows x 33 columns]

# %% [markdown]
# ## Subset to just infected non-doublet cells with at least one barcoded viral gene

# %% [markdown]
# To analyze progeny production and its relation to viral transcription, we subset on the following cells of interest:
#  - infected
#  - not a known doublet (not a mix of viral tags)
#  - expresses at least one of the barcoded viral genes in the supernatant (HA or NA)

# %%
min_viral_barcode_freq = 1e-5  # value assigned to unobserved viral barcodes

print(f"Starting with {integrated_data['cell_barcode'].nunique()} cells.")

infected_cells = integrated_data.query("infected == 'infected'")
print(f"Retaining the {infected_cells['cell_barcode'].nunique()} infected cells.")

infected_cells = infected_cells.query("infecting_viral_tag != 'both'")
print(f"Retaining the {infected_cells['cell_barcode'].nunique()} cells with just one viral tag.")

infected_cells = infected_cells.query("barcoded_gene.notnull()", engine="python")
print(f"Retaining the {infected_cells['cell_barcode'].nunique()} expressing at least one barcoded viral gene.")

# aggregate observed viral barcodes for each gene and cell
infected_cells = (
    infected_cells
    .groupby(["cell_barcode", "barcoded_gene"], as_index=False)
    .aggregate(
        n_viral_barcodes=pd.NamedAgg("viral_barcode", lambda v: v.astype(bool).astype(int).sum()),
        viral_barcodes=pd.NamedAgg("viral_barcode", "; ".join),
        freq_supernatant=pd.NamedAgg("freq_supernatant", "sum"),
        freq_second_infection=pd.NamedAgg("freq_second_infection", "sum"),
    )
)
assert infected_cells.notnull().all().all()

# get barcoded viral genes
barcoded_genes = infected_cells["barcoded_gene"].unique().tolist()

# now pivot so just one row per cell
pivoted_dfs = []
for col_to_pivot, fill_value in [
    ("n_viral_barcodes", 0),
    ("viral_barcodes", ""),
    ("freq_supernatant", pd.NA),
    ("freq_second_infection", pd.NA),
]:
    pivoted_dfs.append(
        infected_cells
        .pivot_table(
            index="cell_barcode",
            columns="barcoded_gene",
            values=col_to_pivot,
            fill_value=fill_value,
            aggfunc='sum',
        )
        .rename_axis(None, axis=1)
        .rename(columns={gene: f"{col_to_pivot}_{gene}" for gene in barcoded_genes})
    )
assert all((pivoted_dfs[0].index == df.index).all() for df in pivoted_dfs)
infected_cells = pd.concat(pivoted_dfs, axis=1).reset_index()

# now add back in cell-specific information
cell_info = (
    integrated_data
    [['cell_barcode', 'infected', 'infecting_viral_tag', 'total_UMIs',
       'viral_UMIs', 'frac_viral_UMIs', 'n_viral_genes'] +
     [c for c in integrated_data.columns if re.match("frac_UMIs_flu|present_flu", c)]
    ]
    .drop_duplicates()
)
assert set(infected_cells["cell_barcode"]).issubset(cell_info["cell_barcode"])
infected_cells = (
    infected_cells
    .merge(cell_info, on="cell_barcode", how="left", validate="one_to_one")
)

# add columns explaining missing genes
present_columns = {c: c.replace("present_flu", "") for c in infected_cells.columns
                   if re.match("present_flu", c)}

infected_cells = (
    infected_cells
    .assign(
        all_viral_genes=lambda x: x['n_viral_genes'] == len(present_columns),
        missing_viral_genes=lambda x: x.apply(lambda row:
            "; ".join(val for (key, val) in present_columns.items() if not row[key]),
            axis=1)
    )
)

infected_cells
# Out:
# Starting with 3372 cells.
# Retaining the 479 infected cells.
# Retaining the 410 cells with just one viral tag.
# Retaining the 396 expressing at least one barcoded viral gene.
#          cell_barcode  n_viral_barcodes_fluHA  n_viral_barcodes_fluNA  \
# 0    AAACGAAGTAGACGTG                       1                       1
# 1    AAAGGATTCTGATGGT                       1                       1
# 2    AAAGGGCCAGGCTACC                       3                       1
# 3    AAAGGGCTCCGCACTT                       3                       2
# 4    AAAGTCCAGTAGAGTT                       1                       1
# ..                ...                     ...                     ...
# 391  TTTAGTCCATCATCCC                       1                       2
# 392  TTTAGTCGTGCTCCGA                       1                       0
# 393  TTTCACAAGCCAAGCA                       1                       1
# 394  TTTGATCTCGCATTGA                       1                       0
# 395  TTTGGAGGTATCGTTG                       1                       1
#
#                                   viral_barcodes_fluHA  \
# 0                                     AAGTAAGCGACATGAG
# 1                                     GTGGAGTCGCCAGTTC
# 2    AAAGTGATCCCCATAC; CATTTAACGCTGTGAG; CGTAGGATGT...
# 3    AATCTACGAGGGAAAC; ATGGATCAGATTTCCT; GCAAAAATAC...
# 4                                     CGCAGGTAACAAGAAG
# ..                                                 ...
# 391                                   AGAACGATATAAATGT
# 392                                   AGTACACGAGGTCGGT
# 393                                   GAACGCACTCATTATC
# 394                                   GGTCACTTGGGTACTG
# 395                                   AGTAAACTTCCTCGCG
#
#                    viral_barcodes_fluNA freq_supernatant_fluHA  \
# 0                      GTAGGCGATAAGTGGA            7.57407e-05
# 1                      TGTTATATTTGTATTG                  1e-05
# 2                      TTTCGACTGTTGATTG             0.00113885
# 3    CTCGTTTTCGGAGTAC; GACTATCTAATTGAGG             0.00353158
# 4                      TTTACTTTAAGTGCTT                  1e-05
# ..                                  ...                    ...
# 391  AGAAACCTCGACATAT; TTGGACGCATTGCAAA                  1e-05
# 392                                                      1e-05
# 393                    GGTATCAGTTATTGTT                  1e-05
# 394                                                      1e-05
# 395                    ACATCTTATTTACACG            0.000694953
#
#     freq_supernatant_fluNA freq_second_infection_fluHA  \
# 0              7.62399e-05                       1e-05
# 1                0.0131834                       1e-05
# 2                    1e-05                       3e-05
# 3              0.000134919                 0.000164641
# 4                    1e-05                       1e-05
# ..                     ...                         ...
# 391                  2e-05                       1e-05
# 392                   <NA>                       1e-05
# 393                  1e-05                       1e-05
# 394                   <NA>                       1e-05
# 395             0.00179022                       1e-05
#
#     freq_second_infection_fluNA  infected  ... present_fluHA  present_fluM  \
# 0                         1e-05  infected  ...          True          True
# 1                      0.077933  infected  ...          True          True
# 2                         1e-05  infected  ...          True          True
# 3                         2e-05  infected  ...          True          True
# 4                         1e-05  infected  ...          True          True
# ..                          ...       ...  ...           ...           ...
# 391                       2e-05  infected  ...          True          True
# 392                        <NA>  infected  ...          True          True
# 393                       1e-05  infected  ...          True          True
# 394                        <NA>  infected  ...          True          True
# 395                 2.81273e-05  infected  ...          True          True
#
#      present_fluNA  present_fluNP  present_fluNS  present_fluPA  \
# 0             True           True           True           True
# 1             True           True           True           True
# 2             True           True           True           True
# 3             True           True           True          False
# 4             True           True           True           True
# ..             ...            ...            ...            ...
# 391           True           True           True          False
# 392           True           True           True           True
# 393           True           True          False           True
# 394           True           True           True           True
# 395           True           True           True           True
#
#      present_fluPB1  present_fluPB2  all_viral_genes  missing_viral_genes
# 0              True            True             True
# 1              True            True             True
# 2              True            True             True
# 3              True            True            False                   PA
# 4              True            True             True
# ..              ...             ...              ...                  ...
# 391            True            True            False                   PA
# 392            True            True             True
# 393           False            True            False              NS; PB1
# 394            True            True             True
# 395            True            True             True
#
# [396 rows x 33 columns]

# %%
infected_cells.columns
# Out:
# Index(['cell_barcode', 'n_viral_barcodes_fluHA', 'n_viral_barcodes_fluNA',
#        'viral_barcodes_fluHA', 'viral_barcodes_fluNA',
#        'freq_supernatant_fluHA', 'freq_supernatant_fluNA',
#        'freq_second_infection_fluHA', 'freq_second_infection_fluNA',
#        'infected', 'infecting_viral_tag', 'total_UMIs', 'viral_UMIs',
#        'frac_viral_UMIs', 'n_viral_genes', 'frac_UMIs_fluHA', 'frac_UMIs_fluM',
#        'frac_UMIs_fluNA', 'frac_UMIs_fluNP', 'frac_UMIs_fluNS',
#        'frac_UMIs_fluPA', 'frac_UMIs_fluPB1', 'frac_UMIs_fluPB2',
#        'present_fluHA', 'present_fluM', 'present_fluNA', 'present_fluNP',
#        'present_fluNS', 'present_fluPA', 'present_fluPB1', 'present_fluPB2',
#        'all_viral_genes', 'missing_viral_genes'],
#       dtype='object')

# %% [markdown]
# ## Plot correlation of viral progeny and transcription

# %%
progeny_vs_transcription_chart = (
    alt.Chart(infected_cells)
    .encode(
        x=alt.Alt.X("frac_viral_UMIs"),
        y=alt.Y"freq_supernatant_fluNA"),
        tooltip=["cell_barcode", "frac_viral_UMIs"]
    )
)

progeny_vs_transcription_chart
# Out:
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# /fh/fast/bloom_j/software/miniconda3/envs/barcoded_flu_pdmH1N1/lib/python3.8/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# /fh/fast/bloom_j/software/miniconda3/envs/barcoded_flu_pdmH1N1/lib/python3.8/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.api.Chart, validating 'required'
#
#         'mark' is a required property
# alt.Chart(...)

# %%
alt.Chart(infected_cells).encode(x=alt.X("total_UMIs", bin=True), y="count()").mark_bar()
# Out:
# alt.Chart(...)

# %%
infected_cells["total_UMIs"].min()
# Out:
# 15997

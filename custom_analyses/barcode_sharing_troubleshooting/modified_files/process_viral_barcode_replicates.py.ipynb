L001_R1_001.fastq.gz\x94s\x8c\x0breplicate_2\x94}\x94h\xcbC\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x95/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-dblSyn-SecondInf-fluNA-B_S32_L001_R1_001.fastq.gz\x94suuuuuuu\x8c\x04rule\x94\x8c process_viral_barcode_replicates\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c[/fh/fast/bloom_j/computational_notebooks/dbacsik/2019/flu_pdmH1N1_barcode_hashing/notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir('/fh/fast/bloom_j/computational_notebooks/dbacsik/2019/flu_pdmH1N1_barcode_hashing');
######## snakemake preamble end #########

# %% [markdown]
# # Process viral barcode replicates
# This notebook plots the correlation between technical replicates of raw viral barcode sequencing data. Then, it calculates the mean frequency of each barcode and exports this value to a CSV. Data source is supernatant or second infection.

# %% [markdown]
# Import Python modules:

# %%
import gzip
import itertools
import random

from IPython.display import display

from dms_variants.constants import CBPALETTE

import editdistance

import numpy as np

import pandas as pd

import plotnine as p9

# %% [markdown]
# Hardcode variables for now:

# %%
viral_bc_in_progeny_csv = snakemake.input.viral_bc_in_progeny_csv
viral_bc_in_progeny_freq_csv = snakemake.output.viral_bc_in_progeny_freq_csv
plot = snakemake.output.plot
expt = snakemake.wildcards.expt

# %% [markdown]
# Load viral barcode counts and pivot dataframe so replicates in two columns.

# %%
viral_bc = pd.read_csv(gzip.open(viral_bc_in_progeny_csv))
viral_bc = pd.merge(viral_bc,
                    (viral_bc
                     .groupby(['source',
                               'tag',
                               'gene',
                               'replicate'])
                     .sum()
                     .reset_index()),
                    on=['source', 'tag', 'gene', 'replicate'],
                    suffixes=('_barcode', '_total'))
viral_bc['freq'] = (viral_bc['count_barcode'] /
                    viral_bc['count_total'])
display(viral_bc)
# Out:
#                   source  tag   gene    replicate           barcode  \
# 0       second_infection  syn  fluHA  replicate_1  GTCAATCAAGATAAGA
# 1       second_infection  syn  fluHA  replicate_1  CATTTACGCTGAATTG
# 2       second_infection  syn  fluHA  replicate_1  AGCTTGGCATGAAAGA
# 3       second_infection  syn  fluHA  replicate_1  CTTCCACTTACAATGT
# 4       second_infection  syn  fluHA  replicate_1  ATCGCTATATGAATCC
# ...                  ...  ...    ...          ...               ...
# 113989       supernatant   wt  fluNA  replicate_2  TTTGCGGATTTACGCA
# 113990       supernatant   wt  fluNA  replicate_2  TTTGGGACATCTTTAA
# 113991       supernatant   wt  fluNA  replicate_2  TTTGTACTCGGTTATA
# 113992       supernatant   wt  fluNA  replicate_2  TTTTAGTATAGATTCG
# 113993       supernatant   wt  fluNA  replicate_2  TTTTGATGGTAAGTTC
#
#         count_barcode  count_total      freq
# 0                6984       558155  0.012513
# 1                3749       558155  0.006717
# 2                3258       558155  0.005837
# 3                1842       558155  0.003300
# 4                1473       558155  0.002639
# ...               ...          ...       ...
# 113989              1       405819  0.000002
# 113990              1       405819  0.000002
# 113991              1       405819  0.000002
# 113992              1       405819  0.000002
# 113993              1       405819  0.000002
#
# [113994 rows x 8 columns]

# %% [markdown]
# ### Plots
# Set theme for plots.

# %%
p9.theme_set(p9.theme_classic())

# %% [markdown]
# Plot number of barcodes identified for each sample:

# %%
n_barcodes_df = (viral_bc
                 .groupby(['source', 'tag', 'gene', 'replicate'])['barcode']
                 .nunique()
                 .reset_index()
                 .rename(columns={'barcode': 'n_unique_barcodes'}))

display(n_barcodes_df)

fig = (p9.ggplot(n_barcodes_df, p9.aes(x='tag',
                                       y='n_unique_barcodes',
                                       fill='replicate')) +
       p9.geom_bar(stat='identity', position='position_dodge') +
       p9.facet_grid('gene~source') +
       p9.theme(figure_size=(3*n_barcodes_df['gene'].nunique(),
                             1.7*n_barcodes_df['source'].nunique()),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.scale_fill_manual(CBPALETTE[0:]))
fig
# Out:
#               source  tag   gene    replicate  n_unique_barcodes
# 0   second_infection  syn  fluHA  replicate_1               7472
# 1   second_infection  syn  fluHA  replicate_2               7211
# 2   second_infection  syn  fluNA  replicate_1               7215
# 3   second_infection  syn  fluNA  replicate_2               6954
# 4   second_infection   wt  fluHA  replicate_1              10491
# 5   second_infection   wt  fluHA  replicate_2              10500
# 6   second_infection   wt  fluNA  replicate_1               9511
# 7   second_infection   wt  fluNA  replicate_2               9318
# 8        supernatant  syn  fluHA  replicate_1               7135
# 9        supernatant  syn  fluHA  replicate_2               7656
# 10       supernatant  syn  fluNA  replicate_1               3096
# 11       supernatant  syn  fluNA  replicate_2               3380
# 12       supernatant   wt  fluHA  replicate_1               8536
# 13       supernatant   wt  fluHA  replicate_2               7824
# 14       supernatant   wt  fluNA  replicate_1               4183
# 15       supernatant   wt  fluNA  replicate_2               3512
# <ggplot: (1449344685960)>

# %% [markdown]
# Plot histogram for each sample:

# %%
fig = (p9.ggplot(viral_bc, p9.aes(x='freq', fill='replicate')) +
       p9.geom_histogram(bins=100) +
       p9.facet_grid('gene+tag~source') +
       p9.scale_y_log10() +
       p9.scale_x_log10() +
       p9.theme(figure_size=(3*viral_bc['source'].nunique(),
                             2*viral_bc['gene'].nunique()),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.ylab('n_barcodes') +
       p9.scale_fill_manual(CBPALETTE[0:]))
fig
# Out:
# /fh/fast/bloom_j/computational_notebooks/dbacsik/2019/flu_pdmH1N1_barcode_hashing/.snakemake/conda/d6cf54c1/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
# /fh/fast/bloom_j/computational_notebooks/dbacsik/2019/flu_pdmH1N1_barcode_hashing/.snakemake/conda/d6cf54c1/lib/python3.8/site-packages/plotnine/layer.py:467: PlotnineWarning: geom_histogram : Removed 734 rows containing missing values.
# <ggplot: (1449336154853)>

# %% [markdown]
# Plot barcode sharing across tags:

# %%
shared_tags = (viral_bc
               .groupby(['source',
                         'gene',
                         'barcode'])
               .agg({'tag': lambda x: ' and '.join(sorted(set(x)))})
               .reset_index())

display(shared_tags)


fig = (p9.ggplot(shared_tags,
                 p9.aes(x='gene',
                        fill='tag')) +
       p9.geom_bar(stat='count') +
       p9.ggtitle(f'barcodes identified in each tag for {expt}') +
       p9.ylab('n_barcodes') +
       p9.coord_flip() +
       p9.facet_grid('source~') +
       p9.theme(figure_size=(7,
                             2*shared_tags['source'].nunique()),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.scale_fill_manual(CBPALETTE[0:]))

# show plot
fig
# Out:
#                  source   gene           barcode  tag
# 0      second_infection  fluHA  AAAAAAAGTGAGGTGA   wt
# 1      second_infection  fluHA  AAAAAAATGAACTTTG   wt
# 2      second_infection  fluHA  AAAAAACCCTGGACGT   wt
# 3      second_infection  fluHA  AAAAAACGAATGGATC  syn
# 4      second_infection  fluHA  AAAAAACGAATGGATT  syn
# ...                 ...    ...               ...  ...
# 83041       supernatant  fluNA  TTTTTGGAATACGCAA   wt
# 83042       supernatant  fluNA  TTTTTGGGTTATTTTG  syn
# 83043       supernatant  fluNA  TTTTTTCTTTACAAGC   wt
# 83044       supernatant  fluNA  TTTTTTTCTAATTGTG  syn
# 83045       supernatant  fluNA  TTTTTTTGAAATGTTT  syn
#
# [83046 rows x 4 columns]
# <ggplot: (1449335768122)>

# %% [markdown]
# Plot barcode frequency by sharing:

# %%
shared_tags_freq = pd.merge(viral_bc,
                            shared_tags,
                            on=['source', 'gene', 'barcode'],
                            suffixes=[None, 's_present'])

display(shared_tags_freq)

fig = (p9.ggplot(shared_tags_freq, p9.aes(x='freq', fill='tags_present')) +
       p9.geom_histogram(bins=100) +
       p9.facet_grid('gene~source') +
       p9.scale_y_log10() +
       p9.scale_x_log10() +
       p9.theme(figure_size=(3*viral_bc['source'].nunique(),
                             2*viral_bc['gene'].nunique()),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.ylab('n_barcodes') +
       p9.scale_fill_manual(CBPALETTE[0:]))
fig
# Out:
#                   source  tag   gene    replicate           barcode  \
# 0       second_infection  syn  fluHA  replicate_1  GTCAATCAAGATAAGA
# 1       second_infection  syn  fluHA  replicate_2  GTCAATCAAGATAAGA
# 2       second_infection   wt  fluHA  replicate_1  GTCAATCAAGATAAGA
# 3       second_infection   wt  fluHA  replicate_2  GTCAATCAAGATAAGA
# 4       second_infection  syn  fluHA  replicate_1  CATTTACGCTGAATTG
# ...                  ...  ...    ...          ...               ...
# 113989       supernatant   wt  fluNA  replicate_2  TTTGCGGATTTACGCA
# 113990       supernatant   wt  fluNA  replicate_2  TTTGGGACATCTTTAA
# 113991       supernatant   wt  fluNA  replicate_2  TTTGTACTCGGTTATA
# 113992       supernatant   wt  fluNA  replicate_2  TTTTAGTATAGATTCG
# 113993       supernatant   wt  fluNA  replicate_2  TTTTGATGGTAAGTTC
#
#         count_barcode  count_total      freq tags_present
# 0                6984       558155  0.012513   syn and wt
# 1                6338       501232  0.012645   syn and wt
# 2                   2       482770  0.000004   syn and wt
# 3                   1       480613  0.000002   syn and wt
# 4                3749       558155  0.006717   syn and wt
# ...               ...          ...       ...          ...
# 113989              1       405819  0.000002           wt
# 113990              1       405819  0.000002           wt
# 113991              1       405819  0.000002           wt
# 113992              1       405819  0.000002           wt
# 113993              1       405819  0.000002           wt
#
# [113994 rows x 9 columns]
# /fh/fast/bloom_j/computational_notebooks/dbacsik/2019/flu_pdmH1N1_barcode_hashing/.snakemake/conda/d6cf54c1/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
# /fh/fast/bloom_j/computational_notebooks/dbacsik/2019/flu_pdmH1N1_barcode_hashing/.snakemake/conda/d6cf54c1/lib/python3.8/site-packages/plotnine/layer.py:467: PlotnineWarning: geom_histogram : Removed 532 rows containing missing values.
# <ggplot: (1449335752081)>

# %% [markdown]
# Plot correlation of barcodes in supernatant and in second infection. Color by presence in each (or both) tags.

# %%
tag_freqs = (shared_tags_freq
             .pivot_table(index=['gene',
                                 'tag',
                                 'barcode',
                                 'tags_present'],
                          columns=['source'],
                          values='freq',
                          aggfunc=np.mean)
             .fillna(0)
             .reset_index())

display(tag_freqs)

fig = (p9.ggplot(tag_freqs,
                 p9.aes(x='supernatant',
                        y='second_infection',
                        color='tags_present')) +
       p9.ggtitle(f'{expt}\n'
                  'barcode counts in supernatant '
                  'and second infection for shared libraries') +
       p9.geom_point(alpha=0.4) +
       p9.facet_grid('gene~tag') +
       p9.scale_x_log10() +
       p9.scale_y_log10() +
       p9.scale_color_manual(CBPALETTE[0:]))
fig
# Out:
# source   gene  tag           barcode tags_present  second_infection  \
# 0       fluHA  syn  AAAAAAAATCACTAAC   syn and wt          0.000000
# 1       fluHA  syn  AAAAAAAGAATTATGA          syn          0.000000
# 2       fluHA  syn  AAAAAACATCGTTTGA          syn          0.000000
# 3       fluHA  syn  AAAAAACGAATGGATC          syn          0.000002
# 4       fluHA  syn  AAAAAACGAATGGATT          syn          0.000337
# ...       ...  ...               ...          ...               ...
# 73442   fluNA   wt  TTTTTGACTCGAAGTG           wt          0.000002
# 73443   fluNA   wt  TTTTTGACTGGAAGTA           wt          0.000002
# 73444   fluNA   wt  TTTTTGGAATACGCAA           wt          0.000055
# 73445   fluNA   wt  TTTTTGGAGGATTCAG           wt          0.000136
# 73446   fluNA   wt  TTTTTTCTTTACAAGC           wt          0.000000
#
# source  supernatant
# 0          0.000002
# 1          0.000002
# 2          0.000002
# 3          0.000000
# 4          0.000000
# ...             ...
# 73442      0.000000
# 73443      0.000000
# 73444      0.000236
# 73445      0.000000
# 73446      0.000002
#
# [73447 rows x 6 columns]
# /fh/fast/bloom_j/computational_notebooks/dbacsik/2019/flu_pdmH1N1_barcode_hashing/.snakemake/conda/d6cf54c1/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
# <ggplot: (1449335755894)>

# %% [markdown]
# Plot frequencies of barcodes and color by which tag (or both) they are found in:

# %%
tag_freqs = (shared_tags_freq
             .pivot_table(index=['source',
                                 'gene',
                                 'barcode',
                                 'tags_present'],
                          columns=['tag'],
                          values='freq',
                          aggfunc=np.mean)
             .fillna(0)
             .reset_index())

display(tag_freqs)

fig = (p9.ggplot(tag_freqs,
                 p9.aes(x='wt',
                        y='syn',
                        color='tags_present')) +
       p9.ggtitle(f'{expt}\n'
                  'barcode counts in wt and syn for shared libraries') +
       p9.geom_point() +
       p9.facet_grid('gene~source') +
       p9.scale_x_log10() +
       p9.scale_y_log10() +
       p9.scale_color_manual(CBPALETTE[1:]))
fig
# Out:
# tag              source   gene           barcode tags_present       syn  \
# 0      second_infection  fluHA  AAAAAAAGTGAGGTGA           wt  0.000000
# 1      second_infection  fluHA  AAAAAAATGAACTTTG           wt  0.000000
# 2      second_infection  fluHA  AAAAAACCCTGGACGT           wt  0.000000
# 3      second_infection  fluHA  AAAAAACGAATGGATC          syn  0.000002
# 4      second_infection  fluHA  AAAAAACGAATGGATT          syn  0.000337
# ...                 ...    ...               ...          ...       ...
# 83041       supernatant  fluNA  TTTTTGGAATACGCAA           wt  0.000000
# 83042       supernatant  fluNA  TTTTTGGGTTATTTTG          syn  0.000011
# 83043       supernatant  fluNA  TTTTTTCTTTACAAGC           wt  0.000000
# 83044       supernatant  fluNA  TTTTTTTCTAATTGTG          syn  0.000003
# 83045       supernatant  fluNA  TTTTTTTGAAATGTTT          syn  0.000002
#
# tag          wt
# 0      0.000136
# 1      0.000002
# 2      0.000053
# 3      0.000000
# 4      0.000000
# ...         ...
# 83041  0.000236
# 83042  0.000000
# 83043  0.000002
# 83044  0.000000
# 83045  0.000000
#
# [83046 rows x 6 columns]
# /fh/fast/bloom_j/computational_notebooks/dbacsik/2019/flu_pdmH1N1_barcode_hashing/.snakemake/conda/d6cf54c1/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
# <ggplot: (1449334526681)>

# %% [markdown]
# Plot frequencies on barcodes that are found in both tags, colored by replicate:

# %%
tag_freqs = (shared_tags_freq
             .query('tags_present == "syn and wt"')
             .pivot_table(index=['source',
                                 'gene',
                                 'barcode',
                                 'replicate'],
                          columns=['tag'],
                          values='freq')
             .fillna(0)
             .reset_index())

display(tag_freqs)

fig = (p9.ggplot(tag_freqs,
                 p9.aes(x='wt',
                        y='syn',
                        color='replicate')) +
       p9.ggtitle(f'{expt}\n'
                  'barcode counts in wt and syn for shared libraries') +
       p9.geom_point() +
       p9.facet_grid('gene~source') +
       p9.scale_x_log10() +
       p9.scale_y_log10() +
       p9.scale_color_manual(CBPALETTE[1:]))
fig
# Out:
# tag             source   gene           barcode    replicate       syn  \
# 0     second_infection  fluHA  AAAGCGTGATTCCTTT  replicate_1  0.000229
# 1     second_infection  fluHA  AAAGCGTGATTCCTTT  replicate_2  0.000211
# 2     second_infection  fluHA  AAATAATGGCGACGCT  replicate_1  0.000530
# 3     second_infection  fluHA  AAATAATGGCGACGCT  replicate_2  0.000539
# 4     second_infection  fluHA  AAATCGTAGGTAAGGT  replicate_1  0.000400
# ...                ...    ...               ...          ...       ...
# 3701       supernatant  fluNA  TTGTCGAAAACGGGAG  replicate_2  0.000598
# 3702       supernatant  fluNA  TTGTGAGCGAAGTGCG  replicate_1  0.000003
# 3703       supernatant  fluNA  TTGTGAGCGAAGTGCG  replicate_2  0.000002
# 3704       supernatant  fluNA  TTTACGCATTGCCGGA  replicate_2  0.000002
# 3705       supernatant  fluNA  TTTAGATTCTTTTATG  replicate_2  0.000002
#
# tag         wt
# 0     0.000002
# 1     0.000000
# 2     0.000002
# 3     0.000000
# 4     0.000000
# ...        ...
# 3701  0.000000
# 3702  0.005526
# 3703  0.004204
# 3704  0.000793
# 3705  0.000335
#
# [3706 rows x 6 columns]
# /fh/fast/bloom_j/computational_notebooks/dbacsik/2019/flu_pdmH1N1_barcode_hashing/.snakemake/conda/d6cf54c1/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
# <ggplot: (1449335801911)>

# %% [markdown]
# Plot correlation of technical replicates

# %%
# Check that replicates fit hardcoded expectations
replicate_names = ['replicate_1', 'replicate_2']
n_replicates = len(replicate_names)
for (_source, _tag, _gene), df in (viral_bc.groupby(['source',
                                                     'tag',
                                                     'gene'])):
    assert set(df['replicate'].unique()) == set(replicate_names), \
        f"Code assumes exactly {n_replicates} replicates per sample."

viral_bc_wide = (viral_bc
                 .pivot_table(index=['source',
                                     'tag',
                                     'gene',
                                     'barcode'],
                              columns='replicate',
                              values='freq')
                 .reset_index()
                 .fillna(0))

viral_bc_wide.columns = ['source',
                         'tag',
                         'gene',
                         'barcode',
                         'replicate_1_freq',
                         'replicate_2_freq']

viral_bc_wide['in_both'] = ((viral_bc_wide['replicate_1_freq'] > 0)
                            & (viral_bc_wide['replicate_2_freq'] > 0))

display(viral_bc_wide)

fig = (p9.ggplot(viral_bc_wide,
                 p9.aes(x='replicate_1_freq',
                        y='replicate_2_freq',
                        color='in_both')) +
       p9.ggtitle(f'viral barcode replicates for experiment {expt}') +
       p9.geom_point(alpha=0.1) +
       p9.facet_grid('source~gene+tag') +
       p9.scale_x_log10() +
       p9.scale_y_log10() +
       p9.theme(figure_size=(3.5*viral_bc_wide['gene'].nunique(),
                             2*viral_bc_wide['source'].nunique()),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.scale_color_manual([CBPALETTE[1], '#000000']))

# save plot
print(f"Saving plot to {plot}")
p9.ggsave(plot=fig, filename=plot, verbose=False)

# show plot
fig
# Out:
#                  source  tag   gene           barcode  replicate_1_freq  \
# 0      second_infection  syn  fluHA  AAAAAACGAATGGATC          0.000000
# 1      second_infection  syn  fluHA  AAAAAACGAATGGATT          0.000351
# 2      second_infection  syn  fluHA  AAAAAATATTCATACG          0.000002
# 3      second_infection  syn  fluHA  AAAAAATCGGTAGAGG          0.000002
# 4      second_infection  syn  fluHA  AAAAAATCGGTAGTAA          0.000002
# ...                 ...  ...    ...               ...               ...
# 85171       supernatant   wt  fluNA  TTTTTACTTTACGAGC          0.000002
# 85172       supernatant   wt  fluNA  TTTTTCGTAAAACTAT          0.000234
# 85173       supernatant   wt  fluNA  TTTTTGACTCGAAGTA          0.000000
# 85174       supernatant   wt  fluNA  TTTTTGGAATACGCAA          0.000236
# 85175       supernatant   wt  fluNA  TTTTTTCTTTACAAGC          0.000002
#
#        replicate_2_freq  in_both
# 0              0.000002    False
# 1              0.000323     True
# 2              0.000000    False
# 3              0.000000    False
# 4              0.000000    False
# ...                 ...      ...
# 85171          0.000000    False
# 85172          0.000000    False
# 85173          0.000870    False
# 85174          0.000000    False
# 85175          0.000000    False
#
# [85176 rows x 7 columns]
# Saving plot to results/viral_progeny/scProgenyProduction_trial1_viral_bc_replicates.pdf
# /fh/fast/bloom_j/computational_notebooks/dbacsik/2019/flu_pdmH1N1_barcode_hashing/.snakemake/conda/d6cf54c1/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
# /fh/fast/bloom_j/computational_notebooks/dbacsik/2019/flu_pdmH1N1_barcode_hashing/.snakemake/conda/d6cf54c1/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
# <ggplot: (1449333426887)>

# %% [markdown]
# Average frequencies and export CSV:

# %%
viral_bc_wide['mean_freq'] = ((viral_bc_wide['replicate_1_freq']
                               + viral_bc_wide['replicate_2_freq'])
                              / 2)

viral_bc_wide.to_csv(viral_bc_in_progeny_freq_csv,
                     columns=['source',
                              'tag',
                              'gene',
                              'barcode',
                              'mean_freq'],
                     index=False)

# %% [markdown]
# Calculate and plot edit distance between observed barcodes:

# %%
sample_size = 1000
records = []
for (source, tag, gene), df in (viral_bc
                                .groupby(['source',
                                          'tag',
                                          'gene'])):
    print(f'Calculating hamming distance for {source} {tag} {gene}.'
          f'\n\tThere are {df["barcode"].nunique()} '
          'unique barcodes in dataset.'
          f'\n\tSampling {sample_size} barcodes for distribution.')
    sample = random.sample(list(df['barcode'].unique()), sample_size)
    for bc_pair in itertools.combinations(sample, 2):
        records.append((source,
                        tag,
                        gene,
                        bc_pair[0],
                        bc_pair[1],
                        editdistance.eval(bc_pair[0], bc_pair[1])))

pairs_df = pd.DataFrame.from_records(records)
pairs_df.columns = ['source',
                    'tag',
                    'gene',
                    'seq_1',
                    'seq_2',
                    'edit_distance']
display(pairs_df)

fig = (p9.ggplot(pairs_df, p9.aes(x='edit_distance')) +
       p9.ggtitle(f'edit distance between barcodes in {expt}') +
       p9.geom_histogram(binwidth=1) +
       p9.facet_grid('gene+tag~source'))

fig
# Out:
# Calculating hamming distance for second_infection syn fluHA.
# 	There are 10217 unique barcodes in dataset.
# 	Sampling 1000 barcodes for distribution.
# Calculating hamming distance for second_infection syn fluNA.
# 	There are 9457 unique barcodes in dataset.
# 	Sampling 1000 barcodes for distribution.
# Calculating hamming distance for second_infection wt fluHA.
# 	There are 13440 unique barcodes in dataset.
# 	Sampling 1000 barcodes for distribution.
# Calculating hamming distance for second_infection wt fluNA.
# 	There are 12380 unique barcodes in dataset.
# 	Sampling 1000 barcodes for distribution.
# Calculating hamming distance for supernatant syn fluHA.
# 	There are 12882 unique barcodes in dataset.
# 	Sampling 1000 barcodes for distribution.
# Calculating hamming distance for supernatant syn fluNA.
# 	There are 5724 unique barcodes in dataset.
# 	Sampling 1000 barcodes for distribution.
# Calculating hamming distance for supernatant wt fluHA.
# 	There are 14100 unique barcodes in dataset.
# 	Sampling 1000 barcodes for distribution.
# Calculating hamming distance for supernatant wt fluNA.
# 	There are 6976 unique barcodes in dataset.
# 	Sampling 1000 barcodes for distribution.
#                    source  tag   gene             seq_1             seq_2  \
# 0        second_infection  syn  fluHA  AAGTTGACTTTATGGA  TAATCATACTTCGTAT
# 1        second_infection  syn  fluHA  AAGTTGACTTTATGGA  TAACCGATATCCGAGA
# 2        second_infection  syn  fluHA  AAGTTGACTTTATGGA  CCTCGGAACTACAACG
# 3        second_infection  syn  fluHA  AAGTTGACTTTATGGA  CGGGGTTTAAAGTACA
# 4        second_infection  syn  fluHA  AAGTTGACTTTATGGA  CAAACTGTCCCAAGGT
# ...                   ...  ...    ...               ...               ...
# 3995995       supernatant   wt  fluNA  AATACTCATCGATGTA  TACGGAGGAACAATTC
# 3995996       supernatant   wt  fluNA  AATACTCATCGATGTA  CTACATTATATAAGTA
# 3995997       supernatant   wt  fluNA  CTACCTGCTATCCCAA  TACGGAGGAACAATTC
# 3995998       supernatant   wt  fluNA  CTACCTGCTATCCCAA  CTACATTATATAAGTA
# 3995999       supernatant   wt  fluNA  TACGGAGGAACAATTC  CTACATTATATAAGTA
#
#          edit_distance
# 0                   10
# 1                    9
# 2                   11
# 3                   11
# 4                    9
# ...                ...
# 3995995             11
# 3995996              7
# 3995997             12
# 3995998              7
# 3995999              9
#
# [3996000 rows x 6 columns]
# <ggplot: (1449333427240)>

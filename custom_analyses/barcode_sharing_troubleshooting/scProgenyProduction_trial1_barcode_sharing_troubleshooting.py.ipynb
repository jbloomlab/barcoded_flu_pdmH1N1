x8c\x0breplicate_1\x94}\x94h\xd3C\x04\x07\xe3\x0c\x10\x94\x85\x94R\x94\x8c\x8b/shared/ngs/illumina/bloom_lab/191223_M03100_0515_000000000-CTH55/Data/Intensities/BaseCalls/dblSyn-rescueTrial2-NA_S2_L001_R1_001.fastq.gz\x94ssuu\x8c\x0bsupernatant\x94}\x94(\x8c\x02wt\x94}\x94(\x8c\x05fluHA\x94}\x94(\x8c\x0breplicate_1\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x8a/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-WT-Sup-fluHA-A_S9_L001_R1_001.fastq.gz\x94s\x8c\x0breplicate_2\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x8b/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-WT-Sup-fluHA-B_S10_L001_R1_001.fastq.gz\x94su\x8c\x05fluNA\x94}\x94(\x8c\x0breplicate_1\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x8b/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-WT-Sup-fluNA-A_S25_L001_R1_001.fastq.gz\x94s\x8c\x0breplicate_2\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x8b/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-WT-Sup-fluNA-B_S26_L001_R1_001.fastq.gz\x94suu\x8c\x03syn\x94}\x94(\x8c\x05fluHA\x94}\x94(\x8c\x0breplicate_1\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x8f/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-dblSyn-Sup-fluHA-A_S11_L001_R1_001.fastq.gz\x94s\x8c\x0breplicate_2\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x8f/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-dblSyn-Sup-fluHA-B_S12_L001_R1_001.fastq.gz\x94su\x8c\x05fluNA\x94}\x94(\x8c\x0breplicate_1\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x8f/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-dblSyn-Sup-fluNA-A_S27_L001_R1_001.fastq.gz\x94s\x8c\x0breplicate_2\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x8f/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-dblSyn-Sup-fluNA-B_S28_L001_R1_001.fastq.gz\x94suuu\x8c\x10second_infection\x94}\x94(\x8c\x02wt\x94}\x94(\x8c\x05fluHA\x94}\x94(\x8c\x0breplicate_1\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x91/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-WT-SecondInf-fluHA-A_S13_L001_R1_001.fastq.gz\x94s\x8c\x0breplicate_2\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x91/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-WT-SecondInf-fluHA-B_S14_L001_R1_001.fastq.gz\x94su\x8c\x05fluNA\x94}\x94(\x8c\x0breplicate_1\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x91/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-WT-SecondInf-fluNA-A_S29_L001_R1_001.fastq.gz\x94s\x8c\x0breplicate_2\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x91/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-WT-SecondInf-fluNA-B_S30_L001_R1_001.fastq.gz\x94suu\x8c\x03syn\x94}\x94(\x8c\x05fluHA\x94}\x94(\x8c\x0breplicate_1\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x95/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-dblSyn-SecondInf-fluHA-A_S15_L001_R1_001.fastq.gz\x94s\x8c\x0breplicate_2\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x95/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-dblSyn-SecondInf-fluHA-B_S16_L001_R1_001.fastq.gz\x94su\x8c\x05fluNA\x94}\x94(\x8c\x0breplicate_1\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x95/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-dblSyn-SecondInf-fluNA-A_S31_L001_R1_001.fastq.gz\x94s\x8c\x0breplicate_2\x94}\x94h\xd3C\x04\x07\xe4\n\r\x94\x85\x94R\x94\x8c\x95/shared/ngs/illumina/bloom_lab/201013_M03100_0625_000000000-JB2KP/Data/Intensities/BaseCalls/Trial2-dblSyn-SecondInf-fluNA-B_S32_L001_R1_001.fastq.gz\x94suuuuuuu\x8c\x04rule\x94\x8c process_viral_barcode_replicates\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c[/fh/fast/bloom_j/computational_notebooks/dbacsik/2019/flu_pdmH1N1_barcode_hashing/notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir('/fh/fast/bloom_j/computational_notebooks/dbacsik/2019/flu_pdmH1N1_barcode_hashing');
######## snakemake preamble end #########

# %% [markdown]
# # Barcode Sharing Troubleshooting
# This notebook plots progeny barcode frequencies. It checks whether viral barcodes are found in `WT` data, `syn` data, or both. In addition, it looks for barcodes in the original WT and syn rescued virus barcode data, as well.
#
# Data for **supernatant and second infection** are from `scProgenyProduction_trial1`.

# %% [markdown]
# ## Notebook setup
#
# Import Python modules:

# %%
import gzip
import itertools
import random

from IPython.display import display

from dms_variants.constants import CBPALETTE

import editdistance

import numpy as np

import pandas as pd

import plotnine as p9
from mizani.formatters import percent_format

# %% [markdown]
# Variables are hardcoded by `snakeamke` in first cell. Specify sample variables.

# %%
viral_bc_in_progeny_csv = 'results/viral_progeny/scProgenyProduction_trial1_bcTroubleShooting_viral_bc_in_progeny.csv.gz'
expt = 'bc_sharing_troubleshooting_scProgenyProduction_trial1'

# %% [markdown]
# ## Process data

# %% [markdown]
# Load viral barcode counts and calculate the frequency of each barcode within a sequencing sample.

# %%
viral_bc = pd.read_csv(gzip.open(viral_bc_in_progeny_csv))

# %%
viral_bc = pd.merge(viral_bc,
                    (viral_bc
                     .groupby(['source',
                               'tag',
                               'gene',
                               'replicate'])
                     .sum()
                     .reset_index()),
                    on=['source', 'tag', 'gene', 'replicate'],
                    suffixes=('_barcode', '_total'))
viral_bc['freq'] = (viral_bc['count_barcode'] /
                    viral_bc['count_total'])
display(viral_bc)
# Out:
#               source  tag   gene    replicate           barcode  \
# 0            plasmid  syn  fluHA  replicate_1  GAGTAAAATTCCTACT
# 1            plasmid  syn  fluHA  replicate_1  AATAATGAACAATGAC
# 2            plasmid  syn  fluHA  replicate_1  ACAGCATAGAAAACGC
# 3            plasmid  syn  fluHA  replicate_1  ATATGACTAGAGGAAC
# 4            plasmid  syn  fluHA  replicate_1  TACCACAAAAAAATAA
# ...              ...  ...    ...          ...               ...
# 4645038  supernatant   wt  fluNA  replicate_2  TTTGCGGATTTACGCA
# 4645039  supernatant   wt  fluNA  replicate_2  TTTGGGACATCTTTAA
# 4645040  supernatant   wt  fluNA  replicate_2  TTTGTACTCGGTTATA
# 4645041  supernatant   wt  fluNA  replicate_2  TTTTAGTATAGATTCG
# 4645042  supernatant   wt  fluNA  replicate_2  TTTTGATGGTAAGTTC
#
#          count_barcode  count_total      freq
# 0                   14      1032246  0.000014
# 1                   13      1032246  0.000013
# 2                   13      1032246  0.000013
# ...

# %% [markdown]
# Check whether each barcode is found in wt and syn rescue virus data:

# %%
rescue_barcodes = ({
                    'fluHA_wt': (set(viral_bc
                                       .query('(source == "rescue") '
                                              'and (tag == "wt") '
                                              'and (gene == "fluHA")')
                                       ['barcode']
                                       .unique())
                                      ),
                    'fluHA_syn': (set(viral_bc
                                       .query('(source == "rescue") '
                                              'and (tag == "syn") '
                                              'and (gene == "fluHA")')
                                       ['barcode']
                                       .unique())
                                      ),
                    'fluNA_wt': (set(viral_bc
                                       .query('(source == "rescue") '
                                              'and (tag == "wt") '
                                              'and (gene == "fluNA")')
                                       ['barcode']
                                       .unique())
                                      ),
                    'fluNA_syn': (set(viral_bc
                                       .query('(source == "rescue") '
                                              'and (tag == "syn") '
                                              'and (gene == "fluNA")')
                                       ['barcode']
                                       .unique()))
})

def check_rescue(row):
    gene = row['gene']
    barcode = row['barcode']
    tags = list()
    for tag in ['wt', 'syn']:
        if barcode in rescue_barcodes[f'{gene}_{tag}']:
            tags.append(tag)
        else:
            pass
    if not tags:
        return 'neither'
    else:
        tag_str = ' and '.join(sorted(set(tags)))
        return(tag_str)

viral_bc['rescue_tags'] = viral_bc.apply(check_rescue, axis=1)

display(viral_bc)
# Out:
#               source  tag   gene    replicate           barcode  \
# 0            plasmid  syn  fluHA  replicate_1  GAGTAAAATTCCTACT
# 1            plasmid  syn  fluHA  replicate_1  AATAATGAACAATGAC
# 2            plasmid  syn  fluHA  replicate_1  ACAGCATAGAAAACGC
# 3            plasmid  syn  fluHA  replicate_1  ATATGACTAGAGGAAC
# 4            plasmid  syn  fluHA  replicate_1  TACCACAAAAAAATAA
# ...              ...  ...    ...          ...               ...
# 4645038  supernatant   wt  fluNA  replicate_2  TTTGCGGATTTACGCA
# 4645039  supernatant   wt  fluNA  replicate_2  TTTGGGACATCTTTAA
# 4645040  supernatant   wt  fluNA  replicate_2  TTTGTACTCGGTTATA
# 4645041  supernatant   wt  fluNA  replicate_2  TTTTAGTATAGATTCG
# 4645042  supernatant   wt  fluNA  replicate_2  TTTTGATGGTAAGTTC
#
#          count_barcode  count_total      freq rescue_tags
# 0                   14      1032246  0.000014     neither
# 1                   13      1032246  0.000013         syn
# ...

# %% [markdown]
# ## Plots
# Set theme for plots.

# %%
p9.theme_set(p9.theme_classic())

# %% [markdown]
# ### General things about each sample
#
# Plot number of reads for each sample:

# %%
fig = (p9.ggplot((viral_bc
                 .groupby(['source', 'tag', 'gene', 'replicate'])['count_barcode']
                 .sum()
                 .reset_index()
                 .rename(columns={'count_barcode': 'n_reads'})),
                 p9.aes(x='tag',
                        y='n_reads',
                        fill='replicate')) +
       p9.geom_bar(stat='identity', position='position_dodge') +
       p9.facet_grid('gene~source') +
       p9.ggtitle('number of reads') +
       p9.scale_y_log10() +
       p9.theme(figure_size=(1.5*viral_bc['source'].nunique(),
                             2*viral_bc['gene'].nunique()),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.scale_fill_manual(CBPALETTE[0:]))
fig
# Out:
# <ggplot: (8748265814667)>

# %% [markdown]
# Plot number of barcodes identified for each sample:

# %%
n_barcodes_df = (viral_bc
                 .groupby(['source', 'tag', 'gene', 'replicate'])['barcode']
                 .nunique()
                 .reset_index()
                 .rename(columns={'barcode': 'n_unique_barcodes'}))

display(n_barcodes_df)

fig = (p9.ggplot(n_barcodes_df, p9.aes(x='tag',
                                       y='n_unique_barcodes',
                                       fill='replicate')) +
       p9.geom_bar(stat='identity', position='position_dodge') +
       p9.facet_grid('gene~source') +
       p9.ggtitle('number of unique barcodes') +
       p9.scale_y_log10() +
       p9.theme(figure_size=(1.5*n_barcodes_df['source'].nunique(),
                             2*n_barcodes_df['gene'].nunique()),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.scale_fill_manual(CBPALETTE[0:]))
fig
# Out:
#               source  tag   gene    replicate  n_unique_barcodes
# 0            plasmid  syn  fluHA  replicate_1             957747
# 1            plasmid  syn  fluNA  replicate_1            1010667
# 2            plasmid   wt  fluHA  replicate_1             970857
# 3            plasmid   wt  fluNA  replicate_1             889670
# 4             rescue  syn  fluHA  replicate_1              94301
# 5             rescue  syn  fluNA  replicate_1              94570
# 6             rescue   wt  fluHA  replicate_1             289140
# 7             rescue   wt  fluNA  replicate_1             224097
# 8   second_infection  syn  fluHA  replicate_1               7472
# 9   second_infection  syn  fluHA  replicate_2               7211
# 10  second_infection  syn  fluNA  replicate_1               7215
# 11  second_infection  syn  fluNA  replicate_2               6954
# 12  second_infection   wt  fluHA  replicate_1              10491
# ...

# %% [markdown]
# Plot frequency histogram for each sample:

# %%
fig = (p9.ggplot(viral_bc, p9.aes(x='freq', fill='replicate')) +
       p9.geom_histogram(bins=100) +
       p9.facet_grid('gene+tag~source') +
       p9.ggtitle('frequency histogram') +
       p9.ylab('n_barcodes') +
       p9.scale_y_log10() +
       p9.scale_x_log10() +
       p9.theme(figure_size=(2.75*viral_bc['source'].nunique(),
                             2*viral_bc['gene'].nunique()),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.scale_fill_manual(CBPALETTE[0:]))
fig
# Out:
# /fh/fast/bloom_j/software/miniconda3/envs/BloomLab/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
# /fh/fast/bloom_j/software/miniconda3/envs/BloomLab/lib/python3.8/site-packages/plotnine/layer.py:467: PlotnineWarning: geom_histogram : Removed 1339 rows containing missing values.
# <ggplot: (8748332242634)>

# %% [markdown]
# Calculate and plot edit distance between a large sample of barcodes for each source:

# %%
sample_size = 1000
records = []
for (source, tag, gene), df in (viral_bc
                                .groupby(['source',
                                          'tag',
                                          'gene'])):
    sample = random.sample(list(df['barcode'].unique()), sample_size)
    for bc_pair in itertools.combinations(sample, 2):
        records.append((source,
                        tag,
                        gene,
                        bc_pair[0],
                        bc_pair[1],
                        editdistance.eval(bc_pair[0], bc_pair[1])))

pairs_df = pd.DataFrame.from_records(records)
pairs_df.columns = ['source',
                    'tag',
                    'gene',
                    'seq_1',
                    'seq_2',
                    'edit_distance']
display(pairs_df)

fig = (p9.ggplot(pairs_df, p9.aes(x='edit_distance')) +
       p9.ggtitle(f'edit distance between barcodes in {expt}') +
       p9.geom_histogram(binwidth=1) +
       p9.facet_grid('gene+tag~source') +
       p9.ggtitle(f'edit distance between sample of {sample_size} unique barcodes') +
       p9.theme(figure_size=(2*viral_bc['source'].nunique(),
                             1.5*viral_bc['gene'].nunique()),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=9),
                legend_title=p9.element_text(size=8),
                legend_title_align='center') 
       )

fig
# Out:
#               source  tag   gene             seq_1             seq_2  \
# 0            plasmid  syn  fluHA  AGCTTATGATGTGGAG  TTGCTGAATTATTGAC
# 1            plasmid  syn  fluHA  AGCTTATGATGTGGAG  GTTAAGATATGATGGT
# 2            plasmid  syn  fluHA  AGCTTATGATGTGGAG  GAAGTGATGGAAAGAA
# 3            plasmid  syn  fluHA  AGCTTATGATGTGGAG  TTAGTGGACACACTTC
# 4            plasmid  syn  fluHA  AGCTTATGATGTGGAG  GACGCTCCGGGACCAG
# ...              ...  ...    ...               ...               ...
# 7991995  supernatant   wt  fluNA  ATAGTGGAAAGGAAGA  GGTTGCGCCGGTAAGA
# 7991996  supernatant   wt  fluNA  ATAGTGGAAAGGAAGA  CACGTTGCGAGGCGAA
# 7991997  supernatant   wt  fluNA  ACTCTGTAAGCTCTTG  GGTTGCGCCGGTAAGA
# 7991998  supernatant   wt  fluNA  ACTCTGTAAGCTCTTG  CACGTTGCGAGGCGAA
# 7991999  supernatant   wt  fluNA  GGTTGCGCCGGTAAGA  CACGTTGCGAGGCGAA
#
#          edit_distance
# 0                    8
# 1                    8
# 2                   10
# 3                   13
# ...

# %% [markdown]
# ## Presence of barcode in rescue virus stock
# Plot frequency of each barcode and whether it is found in `wt` rescued virus stock, `syn` rescued virus stock, `both`, or `neither`.

# %%
fig = (p9.ggplot(viral_bc, p9.aes(x='freq', fill='rescue_tags')) +
       p9.geom_histogram(bins=100) +
       p9.facet_grid('gene+tag~source') +
       p9.ggtitle('frequency histogram') +
       p9.ylab('n_barcodes') +
       p9.scale_y_log10() +
       p9.scale_x_log10() +
       p9.theme(figure_size=(2.75*viral_bc['source'].nunique(),
                             2*viral_bc['gene'].nunique()),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.scale_fill_manual(CBPALETTE[0:]))
fig
# Out:
# /fh/fast/bloom_j/software/miniconda3/envs/BloomLab/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
# /fh/fast/bloom_j/software/miniconda3/envs/BloomLab/lib/python3.8/site-packages/plotnine/layer.py:467: PlotnineWarning: geom_histogram : Removed 4236 rows containing missing values.
# <ggplot: (8748389037677)>

# %% [markdown]
# ### Barcode sharing
# Plot barcode sharing across tags from the same source (e.g. supernatant, second infection, etc...):

# %%
shared_tags_export = (viral_bc
               .groupby(['source',
                         'gene',
                         'barcode'])
               .agg({'tag': lambda x: ' and '.join(sorted(set(x))),
                     'freq': lambda x: sum(x)})
               .reset_index())

# Export all barcodes, and annotate what tags the barcode is found in.
shared_tags_export = (shared_tags_export
                      .query('source == "supernatant"')
                      .rename(columns={'barcode': 'viral_barcode',
                                       'tag': 'present_in_supernatant_tags'}))

shared_tags_export.to_csv(f'results/viral_progeny/{expt}_viral_bc_tags.csv',
                          columns=['gene',
                                   'viral_barcode',
                                   'present_in_supernatant_tags'],
                          index=False)

display(shared_tags_export)
# Out:
#               source   gene     viral_barcode present_in_supernatant_tags  \
# 4574965  supernatant  fluHA  AAAAAAAATCACTAAC                  syn and wt
# 4574966  supernatant  fluHA  AAAAAAAGAATTATGA                         syn
# 4574967  supernatant  fluHA  AAAAAACAGTATTAGG                          wt
# 4574968  supernatant  fluHA  AAAAAACATCGTTTGA                         syn
# 4574969  supernatant  fluHA  AAAAAACCCTGGACGT                          wt
# ...              ...    ...               ...                         ...
# 4612736  supernatant  fluNA  TTTTTGGAATACGCAA                          wt
# 4612737  supernatant  fluNA  TTTTTGGGTTATTTTG                         syn
# 4612738  supernatant  fluNA  TTTTTTCTTTACAAGC                          wt
# 4612739  supernatant  fluNA  TTTTTTTCTAATTGTG                         syn
# 4612740  supernatant  fluNA  TTTTTTTGAAATGTTT                         syn
#
#              freq
# 4574965  0.000004
# 4574966  0.000002
# 4574967  0.000002
# ...

# %%
shared_tags = (viral_bc
               .groupby(['source',
                         'gene',
                         'barcode',
                         'replicate'])
               .agg({'tag': lambda x: ' and '.join(sorted(set(x))),
                     'freq': lambda x: sum(x)})
               .reset_index())

display(shared_tags)
# Out:
#               source   gene           barcode    replicate  tag          freq
# 0            plasmid  fluHA  AAAAAAAAAACCCCCA  replicate_1  syn  9.687613e-07
# 1            plasmid  fluHA  AAAAAAAAAACCCGGA  replicate_1  syn  9.687613e-07
# 2            plasmid  fluHA  AAAAAAAAAACGATAT  replicate_1   wt  9.304567e-07
# 3            plasmid  fluHA  AAAAAAAAAATCACCG  replicate_1  syn  1.937523e-06
# 4            plasmid  fluHA  AAAAAAAAAATGACGC  replicate_1  syn  9.687613e-07
# ...              ...    ...               ...          ...  ...           ...
# 4641880  supernatant  fluNA  TTTTTGGAATACGCAA  replicate_1   wt  2.363517e-04
# 4641881  supernatant  fluNA  TTTTTGGGTTATTTTG  replicate_1  syn  1.148478e-05
# 4641882  supernatant  fluNA  TTTTTTCTTTACAAGC  replicate_1   wt  2.002980e-06
# 4641883  supernatant  fluNA  TTTTTTTCTAATTGTG  replicate_1  syn  2.871195e-06
# 4641884  supernatant  fluNA  TTTTTTTGAAATGTTT  replicate_2  syn  2.256440e-06
#
# [4641885 rows x 6 columns]

# %%
frac_shared_tags = (shared_tags
                    .groupby(['source',
                              'gene',
                              'tag',
                              'replicate'])
                    .count()
                    .drop('freq', axis=1)
                    .reset_index())

frac_shared_tags = pd.merge(frac_shared_tags,
                            (frac_shared_tags
                             .groupby(['source',
                                       'gene',
                                       'replicate'])
                             .sum()
                             .reset_index()
                             .rename(columns={'barcode': 'count_total'})),
                            on=['source','gene', 'replicate'])

frac_shared_tags['frac_barcodes'] = (frac_shared_tags['barcode'] /
                                     frac_shared_tags['count_total'])

display(frac_shared_tags)
# Out:
#               source   gene         tag    replicate  barcode  count_total  \
# 0            plasmid  fluHA         syn  replicate_1   957371      1928228
# 1            plasmid  fluHA  syn and wt  replicate_1      376      1928228
# 2            plasmid  fluHA          wt  replicate_1   970481      1928228
# 3            plasmid  fluNA         syn  replicate_1  1010157      1899827
# 4            plasmid  fluNA  syn and wt  replicate_1      510      1899827
# 5            plasmid  fluNA          wt  replicate_1   889160      1899827
# 6             rescue  fluHA         syn  replicate_1    94061       383201
# 7             rescue  fluHA  syn and wt  replicate_1      240       383201
# 8             rescue  fluHA          wt  replicate_1   288900       383201
# 9             rescue  fluNA         syn  replicate_1    94342       318439
# 10            rescue  fluNA  syn and wt  replicate_1      228       318439
# ...

# %%
fig = (p9.ggplot(frac_shared_tags,
                 p9.aes(x='gene',
                        y='frac_barcodes',
                        fill='tag')) +
       p9.geom_bar(stat='identity') +
       p9.ggtitle('fraction of unique barcodes in wt or syn for each source') +
       p9.facet_grid('~source+replicate') +
       p9.theme(figure_size=(2.5*frac_shared_tags['source'].nunique(), 3),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.scale_fill_manual(CBPALETTE[0:]))

# show plot
fig
# Out:
# <ggplot: (8748417836590)>

# %%
fig = (p9.ggplot(shared_tags,
                 p9.aes(x='gene',
                        y='freq',
                        fill='tag')) +
       p9.geom_bar(stat='identity') +
       p9.ggtitle('fraction of reads in wt or syn for each source') +
       p9.facet_grid('~source+replicate') +
       p9.theme(figure_size=(2.5*shared_tags['source'].nunique(), 3),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.scale_fill_manual(CBPALETTE[0:]))

# show plot
fig
# Out:
# <ggplot: (8748265809059)>

# %% [markdown]
# Plot barcode frequency by sharing:

# %%
viral_bc = pd.merge(viral_bc,
                    shared_tags.drop('freq', axis=1),
                    on=['source', 'gene', 'barcode', 'replicate'],
                    suffixes=[None, 's_present'])

display(viral_bc)

fig = (p9.ggplot(viral_bc, p9.aes(x='freq', fill='tags_present')) +
       p9.geom_histogram(bins=100) +
       p9.facet_grid('gene~source+replicate') +
       p9.scale_y_log10() +
       p9.scale_x_log10() +
       p9.theme(figure_size=(3*viral_bc['source'].nunique(),
                             2*viral_bc['gene'].nunique()),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.ylab('n_barcodes') +
       p9.scale_fill_manual(CBPALETTE[0:]))
fig
# Out:
#               source  tag   gene    replicate           barcode  \
# 0            plasmid  syn  fluHA  replicate_1  GAGTAAAATTCCTACT
# 1            plasmid  syn  fluHA  replicate_1  AATAATGAACAATGAC
# 2            plasmid  syn  fluHA  replicate_1  ACAGCATAGAAAACGC
# 3            plasmid  syn  fluHA  replicate_1  ATATGACTAGAGGAAC
# 4            plasmid  syn  fluHA  replicate_1  TACCACAAAAAAATAA
# ...              ...  ...    ...          ...               ...
# 4645038  supernatant   wt  fluNA  replicate_2  TTTGCGGATTTACGCA
# 4645039  supernatant   wt  fluNA  replicate_2  TTTGGGACATCTTTAA
# 4645040  supernatant   wt  fluNA  replicate_2  TTTGTACTCGGTTATA
# 4645041  supernatant   wt  fluNA  replicate_2  TTTTAGTATAGATTCG
# 4645042  supernatant   wt  fluNA  replicate_2  TTTTGATGGTAAGTTC
#
#          count_barcode  count_total      freq rescue_tags tags_present
# 0                   14      1032246  0.000014     neither          syn
# ...

# %% [markdown]
# Plot frequencies of barcodes and color by which tag (or both) they are found in:

# %%
tag_freqs = (viral_bc
             .pivot_table(index=['source',
                                 'gene',
                                 'barcode',
                                 'tags_present',
                                 'replicate'],
                          columns=['tag'],
                          values='freq')
             .fillna(0)
             .reset_index())

display(tag_freqs)

fig = (p9.ggplot(tag_freqs,
                 p9.aes(x='wt',
                        y='syn',
                        color='tags_present')) +
       p9.ggtitle(f'{expt}\n'
                  'barcode freqs in wt and syn') +
       p9.geom_point() +
       p9.facet_grid('gene~source+replicate') +
       p9.theme(figure_size=(10, 4),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.scale_x_log10() +
       p9.scale_y_log10() +
       p9.scale_color_manual(CBPALETTE[1:]))
fig
# Out:
# tag           source   gene           barcode tags_present    replicate  \
# 0            plasmid  fluHA  AAAAAAAAAACCCCCA          syn  replicate_1
# 1            plasmid  fluHA  AAAAAAAAAACCCGGA          syn  replicate_1
# 2            plasmid  fluHA  AAAAAAAAAACGATAT           wt  replicate_1
# 3            plasmid  fluHA  AAAAAAAAAATCACCG          syn  replicate_1
# 4            plasmid  fluHA  AAAAAAAAAATGACGC          syn  replicate_1
# ...              ...    ...               ...          ...          ...
# 4641880  supernatant  fluNA  TTTTTGGAATACGCAA           wt  replicate_1
# 4641881  supernatant  fluNA  TTTTTGGGTTATTTTG          syn  replicate_1
# 4641882  supernatant  fluNA  TTTTTTCTTTACAAGC           wt  replicate_1
# 4641883  supernatant  fluNA  TTTTTTTCTAATTGTG          syn  replicate_1
# 4641884  supernatant  fluNA  TTTTTTTGAAATGTTT          syn  replicate_2
#
# tag               syn            wt
# 0        9.687613e-07  0.000000e+00
# ...

# %% [markdown]
# Plot how often each barcode is found in the rescued virus data:

# %%
temp_df = (viral_bc
           .groupby(['source',
                     'gene',
                     'tag',
                     'replicate',
                     'tags_present',
                     'rescue_tags'])
             .count()
             .reset_index()
            )


temp_df = temp_df[['source',
                   'gene',
                   'tag',
                   'replicate',
                   'tags_present',
                   'rescue_tags',
                   'count_barcode']]

temp_df = pd.merge(temp_df,
                    (temp_df
                     .groupby(['source',
                               'tag',
                               'gene',
                               'replicate'])
                     .sum()
                     .reset_index()),
                    on=['source', 'tag', 'gene', 'replicate'],
                    suffixes=('_group', '_total'))

temp_df['frac'] = (temp_df['count_barcode_group'] /
                   temp_df['count_barcode_total'])

display(temp_df)

fig = (p9.ggplot(temp_df,
                p9.aes(x='tags_present',
                       y='frac',
                       fill='rescue_tags')) +
       p9.geom_bar(stat='identity') +
       p9.facet_grid('gene+tag~source+replicate') +
       p9.theme(figure_size=(12,6),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.scale_fill_manual(CBPALETTE[0:])
      )

fig
# Out:
#           source   gene  tag    replicate tags_present rescue_tags  \
# 0        plasmid  fluHA  syn  replicate_1          syn     neither
# 1        plasmid  fluHA  syn  replicate_1          syn         syn
# 2        plasmid  fluHA  syn  replicate_1          syn  syn and wt
# 3        plasmid  fluHA  syn  replicate_1          syn          wt
# 4        plasmid  fluHA  syn  replicate_1   syn and wt     neither
# ..           ...    ...  ...          ...          ...         ...
# 152  supernatant  fluNA   wt  replicate_2   syn and wt          wt
# 153  supernatant  fluNA   wt  replicate_2           wt     neither
# 154  supernatant  fluNA   wt  replicate_2           wt         syn
# 155  supernatant  fluNA   wt  replicate_2           wt  syn and wt
# 156  supernatant  fluNA   wt  replicate_2           wt          wt
#
#      count_barcode_group  count_barcode_total      frac
# 0                 947036               957747  0.988816
# ...

# %% [markdown]
# ### Source frequency plots
# Plot correlation for barcode frequencies in plasmid and rescue:

# %%
tag_freqs = (viral_bc
             .pivot_table(index=['gene',
                                 'tag',
                                 'barcode',
                                 'tags_present'],
                          columns=['source'],
                          values='freq')
             .fillna(0)
             .reset_index())

display(tag_freqs)

fig = (p9.ggplot(tag_freqs,
                 p9.aes(x='plasmid',
                        y='rescue',
                        color='tags_present')) +
       p9.ggtitle(f'{expt}\n'
                  'barcode counts in plasmid '
                  'and resced virus') +
       p9.geom_point(alpha=0.4) +
       p9.facet_grid('gene~tag') +
       p9.theme(figure_size=(4, 4),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.scale_x_log10() +
       p9.scale_y_log10() +
       p9.scale_color_manual(CBPALETTE[0:]))
fig
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-9bac2bba59fe> in <module>
# ----> 1 tag_freqs = (viral_bc
#       2              .pivot_table(index=['gene',
#       3                                  'tag',
#       4                                  'barcode',
#       5                                  'tags_present'],
#
# /fh/fast/bloom_j/software/miniconda3/envs/BloomLab/lib/python3.8/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6824         from pandas.core.reshape.pivot import pivot_table
#    6825
# -> 6826         return pivot_table(
#    6827             self,
#    6828             values=values,
#
# ...

# %% [markdown]
# Plot correlation of barcodes in supernatant and in second infection. Color by presence in each (or both) tags.

# %%
fig = (p9.ggplot(tag_freqs,
                 p9.aes(x='supernatant',
                        y='second_infection',
                        color='tags_present')) +
       p9.ggtitle(f'{expt}\n'
                  'barcode counts in supernatant '
                  'and second infection') +
       p9.geom_point(alpha=0.4) +
       p9.facet_grid('gene~tag') +
       p9.theme(figure_size=(4, 4),
                plot_title=p9.element_text(size=10),
                axis_title=p9.element_text(size=10),
                legend_title=p9.element_text(size=9),
                legend_title_align='center') +
       p9.scale_x_log10() +
       p9.scale_y_log10() +
       p9.scale_color_manual(CBPALETTE[0:]))
fig
